# %% [markdown]
# https://www.perplexity.ai/search/88657a74-a8c6-49a9-b9cf-0884a64ac45d

# %%
#加入中文字型
#先安裝wget %開頭會顯示執行結果及注意事項 !開頭僅會顯示執行結果
# %pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\user\miniconda3\envs\chihlee1\lib\site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#加入中文字型
#下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
#加入中文字型
#執行(取用)中文字型
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

# %%
#標準寫法
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt

t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
# print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)
figure, axes = plt.subplots()
axes.plot(t, y1, marker='*', linestyle='', label="90")
axes.plot(t, y2, marker='s', linestyle='-.', label="0")
axes.plot(t, y3, marker='^', linestyle='--', label="-90")   #linestyle='-'(實線) = 預設
axes.legend(loc='upper right', bbox_to_anchor=(1.2, 1))   #顯示圖示說明
axes.set_title("sin()的正弦波")
axes.set_xlabel("圓周率")
axes.set_ylabel("正弦波值")
plt.show()
plt.close()

# %% [markdown]
# ## 簡易寫法,使用plt的module
# ## 如果沒有Figure,幫我建1個Figure
# ## 如果有Figure,就用這個Figure
# ## 如果沒有Axes,幫我建1個Axes
# ## 如果有Axes,就用這個Axes

# %%
#簡易寫法
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt

t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
# print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)
plt.plot(t, y1, marker='*', linestyle='', label="90")
plt.plot(t, y2, marker='s', linestyle='-.', label="0")
plt.plot(t, y3, marker='^', linestyle='--', label="-90")   #linestyle='-'(實線) = 預設
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))   #顯示圖示說明
plt.title("sin()的正弦波")
plt.xlabel("圓周率")
plt.ylabel("正弦波值")
plt.show()
plt.close()
